# %% [markdown]
# <a href="https://colab.research.google.com/github/agemagician/ProtTrans/blob/master/Prediction/ProtBert-BFD-Predict-SS3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h3>Predict secondary structure 3 states using ProtBert-BFD model</h3>
# <h4>You can make free prediction online through this
# <a href="https://huggingface.co/Rostlab/prot_bert_bfd_ss3?text=N+L+Y+I+Q+W+L+K+D+G+G+P+S+S+G+R+P+P+P+S">Link</a></h4>

# %% [markdown]
# **1. Load necessry libraries including huggingface transformers**

# %%
# !pip install -q transformers
# Out:
#      |████████████████████████████████| 1.1MB 2.8MB/s
#      |████████████████████████████████| 890kB 17.8MB/s
#      |████████████████████████████████| 3.0MB 20.0MB/s
#      |████████████████████████████████| 1.1MB 44.3MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification, TokenClassificationPipeline
import re

# %% [markdown]
# **2. Load the token classification pipeline and load it into the GPU if avilabile**

# %%
pipeline = TokenClassificationPipeline(
    model=AutoModelForTokenClassification.from_pretrained("Rostlab/prot_bert_bfd_ss3"),
    tokenizer=AutoTokenizer.from_pretrained("Rostlab/prot_bert_bfd_ss3", skip_special_tokens=True),
    device=0
)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=769.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1676081643.0, style=ProgressStyle(descr…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=81.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=112.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=86.0, style=ProgressStyle(description_w…

# %% [markdown]
# **3. Create or load sequences and map rarely occured amino acids (U,Z,O,B) to (X)**

# %%
sequences_Example = ["M G A E E E D T A I L Y P F T I S G N D R N G N F T I N F K G T P N S T N N G C I G Y S Y N G D W E K I E W E G S C D G N G N L V V E V P M S K I P A G V T S G E I Q I W W H S G D L K M T D Y K A L E H H H H H H",
                     "M N K Y L F E L P Y E R S E P G W T I R S Y F D L M Y N E N R F L D A V E N I V N K E S Y I L D G I Y C N F P D M N S Y D E S E H F E G V E F A V G Y P P D E D D I V I V S E E T C F E Y V R L A C E K Y L Q L H P E D T E K V N K L L S K I P S A G H H H H H H"]

# %%
sequences_Example = [re.sub(r"[UZOB]", "X", sequence) for sequence in sequences_Example]

# %% [markdown]
# **4. Make Prediction**

# %%
pipeline(sequences_Example)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# [[{'entity': 'C', 'index': 0, 'score': 0.8275257349014282, 'word': '[CLS]'},
#   {'entity': 'C', 'index': 1, 'score': 0.9472618103027344, 'word': 'M'},
#   {'entity': 'C', 'index': 2, 'score': 0.9475012421607971, 'word': 'G'},
#   {'entity': 'C', 'index': 3, 'score': 0.9477542638778687, 'word': 'A'},
#   {'entity': 'C', 'index': 4, 'score': 0.9472202062606812, 'word': 'E'},
#   {'entity': 'C', 'index': 5, 'score': 0.9448590278625488, 'word': 'E'},
#   {'entity': 'C', 'index': 6, 'score': 0.9348288774490356, 'word': 'E'},
#   {'entity': 'C', 'index': 7, 'score': 0.8857706785202026, 'word': 'D'},
#   {'entity': 'C', 'index': 8, 'score': 0.6677241921424866, 'word': 'T'},
#   {'entity': 'E', 'index': 9, 'score': 0.5667221546173096, 'word': 'A'},
#   {'entity': 'E', 'index': 10, 'score': 0.8178302049636841, 'word': 'I'},
#   {'entity': 'E', 'index': 11, 'score': 0.8183654546737671, 'word': 'L'},
#   {'entity': 'E', 'index': 12, 'score': 0.6453078985214233, 'word': 'Y'},
#   {'entity': 'E', 'index': 13, 'score': 0.5493001341819763, 'word': 'P'},
#   {'entity': 'E', 'index': 14, 'score': 0.8408302068710327, 'word': 'F'},
#   {'entity': 'E', 'index': 15, 'score': 0.9241619110107422, 'word': 'T'},
#   {'entity': 'E', 'index': 16, 'score': 0.8713455200195312, 'word': 'I'},
#   {'entity': 'E', 'index': 17, 'score': 0.707453727722168, 'word': 'S'},
#   {'entity': 'C', 'index': 18, 'score': 0.5665996074676514, 'word': 'G'},
#   {'entity': 'C', 'index': 19, 'score': 0.6356309652328491, 'word': 'N'},
#   {'entity': 'C', 'index': 20, 'score': 0.76437908411026, 'word': 'D'},
#   {'entity': 'C', 'index': 21, 'score': 0.6051315665245056, 'word': 'R'},
#   {'entity': 'C', 'index': 22, 'score': 0.7649908661842346, 'word': 'N'},
#   {'entity': 'C', 'index': 23, 'score': 0.6037985682487488, 'word': 'G'},
#   {'entity': 'E', 'index': 24, 'score': 0.8581196069717407, 'word': 'N'},
#   {'entity': 'E', 'index': 25, 'score': 0.9337257146835327, 'word': 'F'},
#   {'entity': 'E', 'index': 26, 'score': 0.9389059543609619, 'word': 'T'},
#   {'entity': 'E', 'index': 27, 'score': 0.9402911067008972, 'word': 'I'},
#   {'entity': 'E', 'index': 28, 'score': 0.9388866424560547, 'word': 'N'},
#   {'entity': 'E', 'index': 29, 'score': 0.9356135129928589, 'word': 'F'},
#   {'entity': 'E', 'index': 30, 'score': 0.921724259853363, 'word': 'K'},
#   {'entity': 'E', 'index': 31, 'score': 0.63937908411026, 'word': 'G'},
#   {'entity': 'C', 'index': 32, 'score': 0.9287058711051941, 'word': 'T'},
#   {'entity': 'C', 'index': 33, 'score': 0.9467818140983582, 'word': 'P'},
#   {'entity': 'C', 'index': 34, 'score': 0.9416871070861816, 'word': 'N'},
#   {'entity': 'C', 'index': 35, 'score': 0.92198646068573, 'word': 'S'},
#   {'entity': 'C', 'index': 36, 'score': 0.7416907548904419, 'word': 'T'},
#   {'entity': 'E', 'index': 37, 'score': 0.6383951306343079, 'word': 'N'},
#   {'entity': 'E', 'index': 38, 'score': 0.7080230116844177, 'word': 'N'},
#   {'entity': 'E', 'index': 39, 'score': 0.8400098085403442, 'word': 'G'},
#   {'entity': 'E', 'index': 40, 'score': 0.9192641973495483, 'word': 'C'},
#   {'entity': 'E', 'index': 41, 'score': 0.9379847645759583, 'word': 'I'},
#   {'entity': 'E', 'index': 42, 'score': 0.937383234500885, 'word': 'G'},
#   {'entity': 'E', 'index': 43, 'score': 0.9385380148887634, 'word': 'Y'},
#   {'entity': 'E', 'index': 44, 'score': 0.9321507811546326, 'word': 'S'},
#   {'entity': 'E', 'index': 45, 'score': 0.861131489276886, 'word': 'Y'},
#   {'entity': 'C', 'index': 46, 'score': 0.9418989419937134, 'word': 'N'},
#   {'entity': 'C', 'index': 47, 'score': 0.9477478861808777, 'word': 'G'},
#   {'entity': 'E', 'index': 48, 'score': 0.5944137573242188, 'word': 'D'},
#   {'entity': 'E', 'index': 49, 'score': 0.7925240993499756, 'word': 'W'},
#   {'entity': 'E', 'index': 50, 'score': 0.9081470370292664, 'word': 'E'},
#   {'entity': 'E', 'index': 51, 'score': 0.9206535220146179, 'word': 'K'},
#   {'entity': 'E', 'index': 52, 'score': 0.894906759262085, 'word': 'I'},
#   {'entity': 'E', 'index': 53, 'score': 0.9185569286346436, 'word': 'E'},
#   {'entity': 'E', 'index': 54, 'score': 0.8734450936317444, 'word': 'W'},
#   {'entity': 'E', 'index': 55, 'score': 0.8395175337791443, 'word': 'E'},
#   {'entity': 'E', 'index': 56, 'score': 0.7336241006851196, 'word': 'G'},
#   {'entity': 'E', 'index': 57, 'score': 0.6841084361076355, 'word': 'S'},
#   {'entity': 'E', 'index': 58, 'score': 0.6669419407844543, 'word': 'C'},
#   {'entity': 'C', 'index': 59, 'score': 0.9364274144172668, 'word': 'D'},
#   {'entity': 'C', 'index': 60, 'score': 0.9442093968391418, 'word': 'G'},
#   {'entity': 'C', 'index': 61, 'score': 0.9285354018211365, 'word': 'N'},
#   {'entity': 'C', 'index': 62, 'score': 0.7500095367431641, 'word': 'G'},
#   {'entity': 'E', 'index': 63, 'score': 0.9005469679832458, 'word': 'N'},
#   {'entity': 'E', 'index': 64, 'score': 0.9322433471679688, 'word': 'L'},
#   {'entity': 'E', 'index': 65, 'score': 0.939567506313324, 'word': 'V'},
#   {'entity': 'E', 'index': 66, 'score': 0.938768208026886, 'word': 'V'},
#   {'entity': 'E', 'index': 67, 'score': 0.9385771155357361, 'word': 'E'},
#   {'entity': 'E', 'index': 68, 'score': 0.8964975476264954, 'word': 'V'},
#   {'entity': 'E', 'index': 69, 'score': 0.8516666293144226, 'word': 'P'},
#   {'entity': 'H', 'index': 70, 'score': 0.9078068137168884, 'word': 'M'},
#   {'entity': 'H', 'index': 71, 'score': 0.9018710851669312, 'word': 'S'},
#   {'entity': 'H', 'index': 72, 'score': 0.8863036632537842, 'word': 'K'},
#   {'entity': 'C', 'index': 73, 'score': 0.9353331923484802, 'word': 'I'},
#   {'entity': 'C', 'index': 74, 'score': 0.9463062286376953, 'word': 'P'},
#   {'entity': 'C', 'index': 75, 'score': 0.9436400532722473, 'word': 'A'},
#   {'entity': 'C', 'index': 76, 'score': 0.9454350471496582, 'word': 'G'},
#   {'entity': 'C', 'index': 77, 'score': 0.746696949005127, 'word': 'V'},
#   {'entity': 'E', 'index': 78, 'score': 0.5424745678901672, 'word': 'T'},
#   {'entity': 'E', 'index': 79, 'score': 0.6602247357368469, 'word': 'S'},
#   {'entity': 'E', 'index': 80, 'score': 0.8310189247131348, 'word': 'G'},
#   {'entity': 'E', 'index': 81, 'score': 0.9219815135002136, 'word': 'E'},
#   {'entity': 'E', 'index': 82, 'score': 0.9369633197784424, 'word': 'I'},
#   {'entity': 'E', 'index': 83, 'score': 0.9395528435707092, 'word': 'Q'},
#   {'entity': 'E', 'index': 84, 'score': 0.9396384954452515, 'word': 'I'},
#   {'entity': 'E', 'index': 85, 'score': 0.9368458986282349, 'word': 'W'},
#   {'entity': 'E', 'index': 86, 'score': 0.9010905623435974, 'word': 'W'},
#   {'entity': 'E', 'index': 87, 'score': 0.6543816924095154, 'word': 'H'},
#   {'entity': 'C', 'index': 88, 'score': 0.831433117389679, 'word': 'S'},
#   {'entity': 'C', 'index': 89, 'score': 0.7531469464302063, 'word': 'G'},
#   {'entity': 'E', 'index': 90, 'score': 0.5100393891334534, 'word': 'D'},
#   {'entity': 'E', 'index': 91, 'score': 0.8948412537574768, 'word': 'L'},
#   {'entity': 'E', 'index': 92, 'score': 0.9271800518035889, 'word': 'K'},
#   {'entity': 'E', 'index': 93, 'score': 0.908760666847229, 'word': 'M'},
#   {'entity': 'E', 'index': 94, 'score': 0.7945729494094849, 'word': 'T'},
#   {'entity': 'E', 'index': 95, 'score': 0.6584959626197815, 'word': 'D'},
#   {'entity': 'E', 'index': 96, 'score': 0.7115831971168518, 'word': 'Y'},
#   {'entity': 'E', 'index': 97, 'score': 0.7451473474502563, 'word': 'K'},
#   {'entity': 'E', 'index': 98, 'score': 0.5142097473144531, 'word': 'A'},
#   {'entity': 'C', 'index': 99, 'score': 0.6867519617080688, 'word': 'L'},
#   {'entity': 'C', 'index': 100, 'score': 0.821393609046936, 'word': 'E'},
#   {'entity': 'C', 'index': 101, 'score': 0.9329626560211182, 'word': 'H'},
#   {'entity': 'C', 'index': 102, 'score': 0.9477421045303345, 'word': 'H'},
#   {'entity': 'C', 'index': 103, 'score': 0.94776451587677, 'word': 'H'},
#   {'entity': 'C', 'index': 104, 'score': 0.9476414322853088, 'word': 'H'},
#   {'entity': 'C', 'index': 105, 'score': 0.9477683305740356, 'word': 'H'},
#   {'entity': 'C', 'index': 106, 'score': 0.9474277496337891, 'word': 'H'},
#   {'entity': 'C', 'index': 107, 'score': 0.946984589099884, 'word': '[SEP]'}],
#  [{'entity': 'C', 'index': 0, 'score': 0.6131646037101746, 'word': '[CLS]'},
#   {'entity': 'C', 'index': 1, 'score': 0.9465440511703491, 'word': 'M'},
#   {'entity': 'C', 'index': 2, 'score': 0.8636539578437805, 'word': 'N'},
#   {'entity': 'C', 'index': 3, 'score': 0.5257901549339294, 'word': 'K'},
#   {'entity': 'E', 'index': 4, 'score': 0.7424765229225159, 'word': 'Y'},
#   {'entity': 'E', 'index': 5, 'score': 0.8453730940818787, 'word': 'L'},
#   {'entity': 'E', 'index': 6, 'score': 0.8725191354751587, 'word': 'F'},
#   {'entity': 'E', 'index': 7, 'score': 0.8721227049827576, 'word': 'E'},
#   {'entity': 'E', 'index': 8, 'score': 0.7141439914703369, 'word': 'L'},
#   {'entity': 'E', 'index': 9, 'score': 0.5851735472679138, 'word': 'P'},
#   {'entity': 'C', 'index': 10, 'score': 0.5749018788337708, 'word': 'Y'},
#   {'entity': 'C', 'index': 11, 'score': 0.5760387182235718, 'word': 'E'},
#   {'entity': 'C', 'index': 12, 'score': 0.6737660765647888, 'word': 'R'},
#   {'entity': 'C', 'index': 13, 'score': 0.8037616610527039, 'word': 'S'},
#   {'entity': 'C', 'index': 14, 'score': 0.9149764776229858, 'word': 'E'},
#   {'entity': 'C', 'index': 15, 'score': 0.9123155474662781, 'word': 'P'},
#   {'entity': 'C', 'index': 16, 'score': 0.7680729031562805, 'word': 'G'},
#   {'entity': 'E', 'index': 17, 'score': 0.5503647327423096, 'word': 'W'},
#   {'entity': 'E', 'index': 18, 'score': 0.7670474052429199, 'word': 'T'},
#   {'entity': 'E', 'index': 19, 'score': 0.7245834469795227, 'word': 'I'},
#   {'entity': 'E', 'index': 20, 'score': 0.7584068775177002, 'word': 'R'},
#   {'entity': 'E', 'index': 21, 'score': 0.7782332897186279, 'word': 'S'},
#   {'entity': 'E', 'index': 22, 'score': 0.5450891256332397, 'word': 'Y'},
#   {'entity': 'E', 'index': 23, 'score': 0.4808180034160614, 'word': 'F'},
#   {'entity': 'H', 'index': 24, 'score': 0.41591018438339233, 'word': 'D'},
#   {'entity': 'H', 'index': 25, 'score': 0.4856455624103546, 'word': 'L'},
#   {'entity': 'C', 'index': 26, 'score': 0.5729040503501892, 'word': 'M'},
#   {'entity': 'C', 'index': 27, 'score': 0.6959247589111328, 'word': 'Y'},
#   {'entity': 'C', 'index': 28, 'score': 0.8216511607170105, 'word': 'N'},
#   {'entity': 'H', 'index': 29, 'score': 0.6163604855537415, 'word': 'E'},
#   {'entity': 'H', 'index': 30, 'score': 0.79344642162323, 'word': 'N'},
#   {'entity': 'H', 'index': 31, 'score': 0.8923274874687195, 'word': 'R'},
#   {'entity': 'H', 'index': 32, 'score': 0.9052574038505554, 'word': 'F'},
#   {'entity': 'H', 'index': 33, 'score': 0.9450740814208984, 'word': 'L'},
#   {'entity': 'H', 'index': 34, 'score': 0.9493446946144104, 'word': 'D'},
#   {'entity': 'H', 'index': 35, 'score': 0.9464212656021118, 'word': 'A'},
#   {'entity': 'H', 'index': 36, 'score': 0.9387038350105286, 'word': 'V'},
#   {'entity': 'H', 'index': 37, 'score': 0.9350541234016418, 'word': 'E'},
#   {'entity': 'H', 'index': 38, 'score': 0.8932720422744751, 'word': 'N'},
#   {'entity': 'H', 'index': 39, 'score': 0.8704873323440552, 'word': 'I'},
#   {'entity': 'H', 'index': 40, 'score': 0.648334264755249, 'word': 'V'},
#   {'entity': 'C', 'index': 41, 'score': 0.6561488509178162, 'word': 'N'},
#   {'entity': 'C', 'index': 42, 'score': 0.837604284286499, 'word': 'K'},
#   {'entity': 'C', 'index': 43, 'score': 0.84413081407547, 'word': 'E'},
#   {'entity': 'C', 'index': 44, 'score': 0.669611394405365, 'word': 'S'},
#   {'entity': 'E', 'index': 45, 'score': 0.6054456830024719, 'word': 'Y'},
#   {'entity': 'E', 'index': 46, 'score': 0.8069885969161987, 'word': 'I'},
#   {'entity': 'E', 'index': 47, 'score': 0.7528795003890991, 'word': 'L'},
#   {'entity': 'E', 'index': 48, 'score': 0.5034689903259277, 'word': 'D'},
#   {'entity': 'E', 'index': 49, 'score': 0.6006215214729309, 'word': 'G'},
#   {'entity': 'E', 'index': 50, 'score': 0.8479710817337036, 'word': 'I'},
#   {'entity': 'E', 'index': 51, 'score': 0.8710526823997498, 'word': 'Y'},
#   {'entity': 'E', 'index': 52, 'score': 0.824790358543396, 'word': 'C'},
#   {'entity': 'E', 'index': 53, 'score': 0.6966034173965454, 'word': 'N'},
#   {'entity': 'C', 'index': 54, 'score': 0.6559807062149048, 'word': 'F'},
#   {'entity': 'C', 'index': 55, 'score': 0.787774384021759, 'word': 'P'},
#   {'entity': 'C', 'index': 56, 'score': 0.8378936648368835, 'word': 'D'},
#   {'entity': 'C', 'index': 57, 'score': 0.5760531425476074, 'word': 'M'},
#   {'entity': 'C', 'index': 58, 'score': 0.611598014831543, 'word': 'N'},
#   {'entity': 'C', 'index': 59, 'score': 0.6760799884796143, 'word': 'S'},
#   {'entity': 'C', 'index': 60, 'score': 0.7278298735618591, 'word': 'Y'},
#   {'entity': 'C', 'index': 61, 'score': 0.8704217672348022, 'word': 'D'},
#   {'entity': 'C', 'index': 62, 'score': 0.6942749619483948, 'word': 'E'},
#   {'entity': 'C', 'index': 63, 'score': 0.681888222694397, 'word': 'S'},
#   {'entity': 'C', 'index': 64, 'score': 0.6822879910469055, 'word': 'E'},
#   {'entity': 'C', 'index': 65, 'score': 0.7869660258293152, 'word': 'H'},
#   {'entity': 'C', 'index': 66, 'score': 0.77342689037323, 'word': 'F'},
#   {'entity': 'C', 'index': 67, 'score': 0.778599739074707, 'word': 'E'},
#   {'entity': 'C', 'index': 68, 'score': 0.5294449925422668, 'word': 'G'},
#   {'entity': 'E', 'index': 69, 'score': 0.8389276266098022, 'word': 'V'},
#   {'entity': 'E', 'index': 70, 'score': 0.9015902280807495, 'word': 'E'},
#   {'entity': 'E', 'index': 71, 'score': 0.9145116806030273, 'word': 'F'},
#   {'entity': 'E', 'index': 72, 'score': 0.9141375422477722, 'word': 'A'},
#   {'entity': 'E', 'index': 73, 'score': 0.9115685224533081, 'word': 'V'},
#   {'entity': 'E', 'index': 74, 'score': 0.8533398509025574, 'word': 'G'},
#   {'entity': 'E', 'index': 75, 'score': 0.5715169310569763, 'word': 'Y'},
#   {'entity': 'C', 'index': 76, 'score': 0.8275185227394104, 'word': 'P'},
#   {'entity': 'C', 'index': 77, 'score': 0.9352931976318359, 'word': 'P'},
#   {'entity': 'C', 'index': 78, 'score': 0.9338452219963074, 'word': 'D'},
#   {'entity': 'C', 'index': 79, 'score': 0.9134625792503357, 'word': 'E'},
#   {'entity': 'C', 'index': 80, 'score': 0.8913602828979492, 'word': 'D'},
#   {'entity': 'C', 'index': 81, 'score': 0.7193333506584167, 'word': 'D'},
#   {'entity': 'E', 'index': 82, 'score': 0.7316705584526062, 'word': 'I'},
#   {'entity': 'E', 'index': 83, 'score': 0.8437203168869019, 'word': 'V'},
#   {'entity': 'E', 'index': 84, 'score': 0.8634613156318665, 'word': 'I'},
#   {'entity': 'E', 'index': 85, 'score': 0.7924679517745972, 'word': 'V'},
#   {'entity': 'E', 'index': 86, 'score': 0.6166418790817261, 'word': 'S'},
#   {'entity': 'H', 'index': 87, 'score': 0.805567741394043, 'word': 'E'},
#   {'entity': 'H', 'index': 88, 'score': 0.8835864663124084, 'word': 'E'},
#   {'entity': 'H', 'index': 89, 'score': 0.8668879866600037, 'word': 'T'},
#   {'entity': 'H', 'index': 90, 'score': 0.8832994699478149, 'word': 'C'},
#   {'entity': 'H', 'index': 91, 'score': 0.9316457509994507, 'word': 'F'},
#   {'entity': 'H', 'index': 92, 'score': 0.9473565220832825, 'word': 'E'},
#   {'entity': 'H', 'index': 93, 'score': 0.9495312571525574, 'word': 'Y'},
#   {'entity': 'H', 'index': 94, 'score': 0.9483944177627563, 'word': 'V'},
#   {'entity': 'H', 'index': 95, 'score': 0.9501760005950928, 'word': 'R'},
#   {'entity': 'H', 'index': 96, 'score': 0.9454850554466248, 'word': 'L'},
#   {'entity': 'H', 'index': 97, 'score': 0.9294523000717163, 'word': 'A'},
#   {'entity': 'H', 'index': 98, 'score': 0.9387345314025879, 'word': 'C'},
#   {'entity': 'H', 'index': 99, 'score': 0.9436284899711609, 'word': 'E'},
#   {'entity': 'H', 'index': 100, 'score': 0.9365288615226746, 'word': 'K'},
#   {'entity': 'H', 'index': 101, 'score': 0.9137965440750122, 'word': 'Y'},
#   {'entity': 'H', 'index': 102, 'score': 0.862026572227478, 'word': 'L'},
#   {'entity': 'H', 'index': 103, 'score': 0.7587964534759521, 'word': 'Q'},
#   {'entity': 'H', 'index': 104, 'score': 0.7093287706375122, 'word': 'L'},
#   {'entity': 'C', 'index': 105, 'score': 0.8209240436553955, 'word': 'H'},
#   {'entity': 'C', 'index': 106, 'score': 0.555199384689331, 'word': 'P'},
#   {'entity': 'C', 'index': 107, 'score': 0.4939238131046295, 'word': 'E'},
#   {'entity': 'C', 'index': 108, 'score': 0.4958508014678955, 'word': 'D'},
#   {'entity': 'H', 'index': 109, 'score': 0.9305429458618164, 'word': 'T'},
#   {'entity': 'H', 'index': 110, 'score': 0.9470694065093994, 'word': 'E'},
#   {'entity': 'H', 'index': 111, 'score': 0.9495404958724976, 'word': 'K'},
#   {'entity': 'H', 'index': 112, 'score': 0.9486314654350281, 'word': 'V'},
#   {'entity': 'H', 'index': 113, 'score': 0.9477540850639343, 'word': 'N'},
#   {'entity': 'H', 'index': 114, 'score': 0.9438964128494263, 'word': 'K'},
#   {'entity': 'H', 'index': 115, 'score': 0.9400120973587036, 'word': 'L'},
#   {'entity': 'H', 'index': 116, 'score': 0.887480616569519, 'word': 'L'},
#   {'entity': 'H', 'index': 117, 'score': 0.5939359068870544, 'word': 'S'},
#   {'entity': 'C', 'index': 118, 'score': 0.710699200630188, 'word': 'K'},
#   {'entity': 'C', 'index': 119, 'score': 0.9334811568260193, 'word': 'I'},
#   {'entity': 'C', 'index': 120, 'score': 0.9352444410324097, 'word': 'P'},
#   {'entity': 'C', 'index': 121, 'score': 0.928385853767395, 'word': 'S'},
#   {'entity': 'C', 'index': 122, 'score': 0.9348800778388977, 'word': 'A'},
#   {'entity': 'C', 'index': 123, 'score': 0.943993091583252, 'word': 'G'},
#   {'entity': 'C', 'index': 124, 'score': 0.9444779753684998, 'word': 'H'},
#   {'entity': 'C', 'index': 125, 'score': 0.9444169998168945, 'word': 'H'},
#   {'entity': 'C', 'index': 126, 'score': 0.9452093243598938, 'word': 'H'},
#   {'entity': 'C', 'index': 127, 'score': 0.9456561803817749, 'word': 'H'},
#   {'entity': 'C', 'index': 128, 'score': 0.9458321928977966, 'word': 'H'},
#   {'entity': 'C', 'index': 129, 'score': 0.9463008046150208, 'word': 'H'},
#   {'entity': 'C', 'index': 130, 'score': 0.9438185095787048, 'word': '[SEP]'}]]
